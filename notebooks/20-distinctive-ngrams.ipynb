# %% [markdown]
# # Urban vs. rural, predictive ngrams

# %% [markdown]
# How does language use on Twitter vary between urban and rural areas?
#
# There are a number of ways to approach these types of questions about linguistic variation. This notebook takes a maximally simple route, to get a sense of how large the difference is and what it might roughly consist of.
#
# - Working with two buckets of tweets - one from cities with population < 10,000 (rural), and the other from cities with population > 1M (urban) - just fit bag-of-words logistic regressions.
# - Then, pull out ngrams with the highest coefficients under the models, words that are most predictive of the two classes.
# - As a bonus, by looking at the performance of the models, we can get a sense of the size / consistency of the difference - the degree to which (very) simple classifiers are able to tell the difference between urban and rural.
#
# The data:
#
# - 2017 decahose through September, ~5 billion tweets (excluding RTs).
# - Geocoded tweets (city or state): **357,061,859**
# - Tweets matched to individual cities: **250,701,213**
# - Unique users for geocoded tweets: **12,709,671**
# - Tweets matched to cities with population < 10,000 (rural): **18,162,300**
# - Tweets matched to cities with population > 1M (urban): **51,694,990**
# - Working samples: **~5M** each for urban and rural.
#
# TODO: Convert to Spark MLlib and run on EC2 with full data?

# %%
import ujson
import numpy as np
import re
import os

from tqdm import tqdm_notebook
from glob import glob

from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
def read_tweets(pattern, fcount=None):
    
    paths = glob(pattern)
    
    if fcount:
        paths = paths[:fcount]
    
    tweets = []
    for path in paths:
        
        with open(path) as fh:
            for line in fh:
                tweet = ujson.loads(line)
                text = re.sub('(#|@|http)\S+', '', tweet['body'])
                tweets.append(text)
                
    return tweets

# %%
rural = read_tweets('../../data/geo-lt10k.json/*.json', 60)

# %%
urban = read_tweets('../../data/geo-gt1m.json/*.json', 20)

# %%
rural_ = rural[:5000000]

# %%
urban_ = urban[:5000000]

# %%
X = rural_ + urban_

# %%
y = ([0] * len(rural_)) + ([1] * len(urban_))

# %%
def train_model(X, y, ngram_range=(1, 1), max_features=1000):
    
    cv = CountVectorizer(
        ngram_range=ngram_range,
        max_features=max_features,
    )
    
    X = cv.fit_transform(X)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    model = LogisticRegression()
    fit = model.fit(X_train, y_train)
    
    y_pred = fit.predict(X_test)
    
    report = classification_report(
        y_test, y_pred, target_names=('rural', 'urban'),
    )
    
    print(report)
    
    return cv, model

# %%
def print_rural(model, names, n=100):
    idxs = model.coef_[0].argsort()
    for idx in idxs[:n]:
        print(model.coef_[0][idx], names[idx])

# %%
def print_urban(model, names, n=100):
    idxs = np.flip(model.coef_[0].argsort(), 0)
    for idx in idxs[:n]:
        print(model.coef_[0][idx], names[idx])

# %%
ng1_cv, ng1_model = train_model(X, y, (1, 1))
# Out:
#              precision    recall  f1-score   support
#
#       rural       0.55      0.63      0.59   1250407
#       urban       0.57      0.49      0.53   1249593
#
# avg / total       0.56      0.56      0.56   2500000

# %%
ng2_cv, ng2_model = train_model(X, y, (2, 2))
# Out:
#              precision    recall  f1-score   support
#
#       rural       0.55      0.27      0.36   1249919
#       urban       0.52      0.79      0.62   1250081
#
# avg / total       0.54      0.53      0.49   2500000

# %%
ng3_cv, ng3_model = train_model(X, y, (3, 3))
# Out:
#              precision    recall  f1-score   support
#
#       rural       0.58      0.11      0.18   1248368
#       urban       0.51      0.92      0.66   1251632
#
# avg / total       0.54      0.51      0.42   2500000

# %% [markdown]
# Why does precision diverge so much in the bigram / trigram models?

# %% [markdown]
# # Rural unigrams

# %%
names1 = ng1_cv.get_feature_names()

# %%
print_rural(ng1_model, names1)
# 0.181041281745 fact that
# 0.181025510355 for her
# 0.179006039757 on his
# 0.177841708284 so can
# 0.177732004499 she was
# 0.174028980778 on that
# 0.173540437585 so we
# 0.173102683425 talking about
# 0.171253870137 but the
# 0.169195133319 on this
# 0.166345189377 is this
# 0.165364452925 where the
# 0.165243653462 when was
# 0.161517076339 looking at
# 0.16085707062 tried to
# 0.160808697307 lot of
# 0.158032275813 of all
# 0.157299805772 to this
# 0.157210790201 no more
# 0.156456956253 let me
# 0.156391453265 watch the

# %% [markdown]
# # Rural trigrams

# %%
names3 = ng3_cv.get_feature_names()

# %%
print_rural(ng3_model, names3)
# Out:
# -5.57083507864 on radio danz
# -3.63054970132 wind mph barometer
# -3.34518541373 rain today 00
# -3.280014639 is on q106
# -3.280014639 on q106 country
# -3.1255147782 falls ny weather
# -3.1255147782 honeoye falls ny
# -3.06769921745 example twitter weather
# -3.06769921745 twitter weather data
# -3.01303028592 in steady temperature
# -2.88289683454 wind speed 0mph
# -2.58945415774 national weather service
# -1.99928366957 today 00 in
# -1.53178036494 severe thunderstorm warning
# -1.52307186509 more and more
# -1.48913220091 left in the
# -1.46045594102 just checked in
# -1.39246784115 good luck to
# -1.36559091991 and people unfollowed
# -1.32264994605 new photo to
# -1.25231886349 out my broadcast
# -1.24434024686 to your profile
# -1.23078147828 lt gt gt
# -1.15512673819 cast your vote
# -1.14720757242 unit name chet
# -1.14720757242 motion detection unit
# -1.14720757242 name chet home
# -1.14720757242 home date time
# -1.14720757242 chet home date
# -1.14720757242 detection unit name
# -1.10396502787 now available for
# -1.09330066176 happy birthday hope
# -1.07049714751 video to facebook
# -1.06535970144 in the running
# -0.994694369288 case you missed
# -0.9497022127 yasss it time
# -0.940396814693 bottom of the
# -0.925601131076 to show you
# -0.885376476491 لا إله إلا
# -0.868028814513 with download today
# -0.852864027455 it out here
# -0.838321598254 me on snapchat
# -0.82991835228 now playing on
# -0.82616697322 to see who
# -0.821421503091 rain since midnight
# -0.779270401549 way to go
# -0.759072000399 you to know
# -0.755658801218 in mplus places
# -0.755658801218 earning in mplus
# -0.744519003012 chance to win
# -0.734291361244 love you too
# -0.729581754963 enter to win
# -0.727380500811 sign the petition
# -0.719120178493 posted new video
# -0.715601830377 miss you too
# -0.698817129638 you and me
# -0.665793573057 just earned the
# -0.639883198918 who visits your
# -0.625722156076 all of our
# -0.613223899508 and one person
# -0.606073251009 go to bed
# -0.605548537738 we will be
# -0.601949918002 love you more
# -0.591777821117 anyone for this
# -0.581090875736 to know who
# -0.573318239478 entered giveaway for
# -0.57094898632 rain last 24
# -0.543150860267 top of the
# -0.53493816613 team see our
# -0.519447939428 have great day
# -0.512158613195 of the season
# -0.508573826367 my best friend
# -0.500914750109 me automatically checked
# -0.497662411571 thank you to
# -0.494272224677 wow just entered
# -0.488213209375 you missed it
# -0.48790187823 so tired of
# -0.485869736102 ready to go
# -0.485739452405 for chance to
# -0.483715042754 first day of
# -0.482111649412 join us for
# -0.479662166608 4th of july
# -0.470866808266 hope you had
# -0.46250872698 on the road
# -0.455318862815 added video to
# -0.45424286893 keep up the
# -0.450757668304 back to school
# -0.449922147674 on my mind
# -0.449172638676 to know that
# -0.446254783943 and click to
# -0.442598918225 one of our
# -0.441089002315 of the week
# -0.429174732057 you so much
# -0.427941066891 do you see
# -0.419498910955 in the morning
# -0.408497865787 in need of
# -0.403442213397 your twitter profile
# -0.40339716063 liked video the
# -0.400186296502 we re read
# -0.398340778605 one person unfollowed

# %% [markdown]
# # Urban trigrams

# %%
print_urban(ng3_model, names3)
# Out:
# 4.90555537594 flight spotted at
# 4.7252154362 10 minute guide
# 4.53995590192 miles away traveling
# 3.52502750963 airlines flight spotted
# 3.23136182996 york city news
# 2.67151760388 work in ca
# 2.50413651048 in san diego
# 2.34591697654 in los angeles
# 2.1258235665 post your tweet
# 2.09473678644 surely interest you
# 2.09473678644 should surely interest
# 2.09473678644 this should surely
# 2.02063228519 your tweet also
# 2.02063228519 tweet also at
# 1.89277433479 can you recommend
# 1.51547029993 com gt gt
# 1.45381027246 click to apply
# 1.42684169082 00 humidity is
# 1.42684169082 gmt 0000 utc
# 1.42684169082 current temperature is
# 1.42684169082 0000 utc current
# 1.42684169082 utc current temperature
# 1.39531984685 you are looking
# 1.23361951049 followed me and
# 1.13122187042 new video to
# 1.11397250174 checked in at
# 1.06937498641 link in bio
# 0.935476410747 latest opening here
# 0.928509021713 in with download
# 0.867254586975 click for details
# 0.842969446075 00 in humidity
# 0.784023203742 the 10 minute
# 0.776872207472 connect have great
# 0.715022071903 in new york
# 0.70871930382 me and people
# 0.698522687926 the new york
# 0.605048554124 have you heard
# 0.599583096049 behind the scenes
# 0.565361980702 our latest opening
# 0.558470455928 be great fit
# 0.529326649498 game of thrones
# 0.484095422552 can you please
# 0.468851785827 broadcast from my
# 0.467743322707 my broadcast from
# 0.457961935256 great fit for
# 0.445003917394 official music video
# 0.433543303357 new york city
# 0.420568001843 what is this
# 0.417268555843 sign up for
# 0.412170299226 what the fuck
# 0.406696030028 looking for work
# 0.397345506365 ve never been
# 0.395614941196 would ve been
# 0.393693143941 thank you so
# 0.388278282826 interested in in
# 0.388005727845 for following me
# 0.375517332582 to talk about
# 0.373252488423 the future of
# 0.371184295619 not to be
# 0.369930712371 in the us
# 0.363574161452 need to know
# 0.356062703079 for work in
# 0.352647737711 need to see
# 0.338600906431 at the same
# 0.336462301347 we re all
# 0.335886526154 on the same
# 0.319498593693 just added this
# 0.305164606029 to work with
# 0.303056804482 the fuck up
# 0.297003491006 thanks for sharing
# 0.296212641458 is the new
# 0.285100899702 at the gym
# 0.281217084315 around the world
# 0.280346193198 this is an
# 0.279727397244 so we can
# 0.278298884252 to go out
# 0.269583482675 had no idea
# 0.265034235419 me on the
# 0.263900767395 in the future
# 0.261315830919 in my head
# 0.260418348834 what going on
# 0.25569545198 have you seen
# 0.255569853774 this is how
# 0.253419784911 do it for
# 0.253371713333 to know about
# 0.252771463619 get to the
# 0.245340120208 these are the
# 0.245068747722 follow happy to
# 0.241774815603 the fuck is
# 0.241111060351 hit me up
# 0.238588831545 shout out to
# 0.238314347514 and they re
# 0.235583835184 the best way
# 0.235420159472 they re not
# 0.234586719653 posted new photo
# 0.234141531315 you know what
# 0.233500980249 on my way
# 0.229398048023 what happens when
# 0.229198466344 trying to make
# 0.227818655908 you for the
