# %%
import pandas as pd

from wordfreq import top_n_list

from twitter_geo.state_word_counts.db import StateWordCount

# %%
tokens = StateWordCount.tokens()

# %%
stopwords = set(top_n_list('en', 300))

# %%
state_counts = StateWordCount.state_counts()

# %%
def compare(key1, key2):
    
    data = []
    for token in StateWordCount.tokens():

        if token in stopwords or len(token) < 3:
            continue

        c1 = StateWordCount.state_token_count(key1, token) or 0
        c2 = StateWordCount.state_token_count(key2, token) or 0

        c1 /= state_counts[key1]
        c2 /= state_counts[key2]

        data.append((token, c1-c2))
        
    return pd.DataFrame(data, columns=('token', 'score'))

# %%
df = compare('CA', 'AL')

# %%
pd.options.display.max_rows = 200

# %%
df.sort_values('score', ascending=False)
# Out:
#               token     score
# 4524            til  0.001049
# 7577           blog  0.000686
# 7658      available  0.000556
# 6930            san  0.000553
# 5356       appeared  0.000422
# 4998            los  0.000374
# 1628           fuck  0.000345
# 6745           wild  0.000331
# 436      california  0.000296
# 3889        angeles  0.000282
# 1162        fucking  0.000265
# 4891            via  0.000263
# 1709          diego  0.000196
# 3689           data  0.000188
# 5555         flight  0.000183
# 1208            app  0.000180
# 5900           hour  0.000167
# 2659         random  0.000159
# 5643        amazing  0.000157
# 6329            hey  0.000156
# 941           using  0.000154
# 8094          thank  0.000152
# 8921        spotted  0.000150
# 909            haha  0.000148
# 9323          santa  0.000148
# 7224            que  0.000141
# 5470           feet  0.000139
# 8239           rock  0.000139
# 237         unknown  0.000134
# 2493         amazon  0.000133
# 6133      marketing  0.000133
# 2255        product  0.000132
# 4806            red  0.000131
# 2231          reply  0.000130
# 5976         follow  0.000130
# 6778           guys  0.000122
# 6733      francisco  0.000119
# 9202          cloud  0.000113
# 1700            opt  0.000112
# 9084         future  0.000111
# 6045           sale  0.000109
# 303            shop  0.000109
# 8987            del  0.000107
# 3053           post  0.000106
# 2546         hahaha  0.000105
# 5918           film  0.000104
# 5769            con  0.000103
# 7803            air  0.000103
# 3505           lady  0.000102
# 4887            omg  0.000100
# 7122            wtf  0.000100
# 8432            bay  0.000099
# 8119           page  0.000099
# 2024         valley  0.000099
# 415        airlines  0.000098
# 4737           cute  0.000097
# 2334           jobs  0.000097
# 752            save  0.000096
# 6           project  0.000096
# 7927           tips  0.000096
# 6171            art  0.000096
# 299            join  0.000096
# 3452         google  0.000094
# 5246            sur  0.000094
# 8394            buy  0.000093
# 7086         online  0.000093
# 3050           fast  0.000092
# 6969         review  0.000091
# 4707         market  0.000091
# 399           beach  0.000088
# 618            asks  0.000087
# 497         support  0.000085
# 6747        install  0.000083
# 4539      hollywood  0.000082
# 1496           tech  0.000080
# 8776            mom  0.000079
# 9191           nice  0.000079
# 647           brand  0.000078
# 9354        digital  0.000077
# 1937          gonna  0.000076
# 7860          apple  0.000075
# 4686          white  0.000074
# 4672          hills  0.000074
# 3995         summer  0.000074
# 7253       interest  0.000073
# 5041           park  0.000073
# 5600           code  0.000073
# 3437        oakland  0.000073
# 4562          super  0.000072
# 4716      collision  0.000072
# 8294         social  0.000072
# 6581         normal  0.000071
# 5096        content  0.000071
# 2126           para  0.000071
# 966          design  0.000071
# 7617            las  0.000070
# 1464           body  0.000069
# 7237          watch  0.000068
# 5299            hot  0.000068
# 3285          vegas  0.000068
# ...             ...       ...
# 341        thankful -0.000058
# 2128            leo -0.000058
# 6736         storms -0.000059
# 3403            yep -0.000059
# 2300           hate -0.000059
# 532         georgia -0.000059
# 6963           damn -0.000059
# 8712           hurt -0.000060
# 3470           wish -0.000060
# 3217           hope -0.000060
# 4209        blessed -0.000061
# 3598          tunes -0.000061
# 8819          heart -0.000062
# 2323          moore -0.000063
# 6262         cancer -0.000064
# 9320          girls -0.000064
# 27            tired -0.000066
# 6038          folks -0.000067
# 5598            bet -0.000068
# 6920           nude -0.000068
# 8571           miss -0.000069
# 597        baseball -0.000069
# 1422          sleep -0.000071
# 8015           girl -0.000071
# 7614            ass -0.000072
# 6503          sweet -0.000072
# 5007          storm -0.000072
# 4121          video -0.000072
# 7546        atlanta -0.000075
# 2641          south -0.000075
# 6916         severe -0.000076
# 8364        florida -0.000077
# 8020           amen -0.000078
# 2080            mph -0.000079
# 8314          wanna -0.000079
# 1549        cleared -0.000079
# 6525           pray -0.000080
# 2285           road -0.000080
# 9221         trying -0.000080
# 1981           baby -0.000081
# 128         college -0.000088
# 6881          obama -0.000088
# 8647       tomorrow -0.000093
# 5650            sex -0.000095
# 11              won -0.000096
# 2879            boy -0.000097
# 8585          swear -0.000099
# 7352            sec -0.000099
# 308          inches -0.000101
# 171           cause -0.000101
# 1328            lol -0.000102
# 3830          coach -0.000103
# 5409           wind -0.000103
# 1705          jesus -0.000105
# 10             roll -0.000106
# 4633         waking -0.000110
# 4404           exit -0.000111
# 6061          photo -0.000112
# 5460         church -0.000115
# 9044        entered -0.000115
# 9361         spread -0.000117
# 8200     montgomery -0.000119
# 3918          liked -0.000119
# 6603         nobody -0.000120
# 4339           thin -0.000123
# 4220      everybody -0.000127
# 6601        earning -0.000133
# 1753        tonight -0.000134
# 6675           hell -0.000138
# 6204           tide -0.000140
# 6509           bout -0.000142
# 5070         mobile -0.000150
# 1485           lord -0.000150
# 3534           word -0.000151
# 861             ion -0.000151
# 8218         chance -0.000168
# 4082       somebody -0.000172
# 6450          flame -0.000172
# 1883          gotta -0.000172
# 6025        weather -0.000175
# 2722         posted -0.000176
# 5189          ready -0.000188
# 1324       football -0.000191
# 322         playing -0.000191
# 2195         county -0.000195
# 8044        morning -0.000212
# 876            rain -0.000222
# 5350       followed -0.000228
# 4294  automatically -0.000264
# 1283        checked -0.000268
# 8289       birthday -0.000276
# 810             amp -0.000282
# 1691            win -0.000330
# 1048     birmingham -0.000341
# 3078          radio -0.000344
# 8368           gone -0.000346
# 6098            don -0.000514
# 2083        alabama -0.001145
# 7114           town -0.002730
# 3805           boys -0.003351
#
# [9376 rows x 2 columns]
