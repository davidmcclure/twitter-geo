# %% [markdown]
# # Urban vs. rural, MA

# %%
import ujson
import numpy as np
import re
import os

from tqdm import tqdm_notebook
from glob import glob

from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
def read_tweets(pattern, fcount=None):
    
    paths = glob(pattern)
    
    if fcount:
        paths = paths[:fcount]
    
    tweets = []
    for path in paths:
        
        with open(path) as fh:
            for line in fh:
                tweet = ujson.loads(line)
                text = re.sub('(#|@|http)\S+', '', tweet['body'])
                tweets.append(text)
                
    return tweets

# %%
rural = read_tweets('../../data/ma-rural.json/*.json')

# %%
urban = read_tweets('../../data/ma-boston.json/*.json')

# %%
X = rural + urban

# %%
y = ([0] * len(rural)) + ([1] * len(urban))

# %%
len(X)
# Out:
# 6479164

# %%
def train_model(X, y, ngram_range=(1, 1), max_features=1000):
    
    cv = CountVectorizer(
        ngram_range=ngram_range,
        max_features=max_features,
    )
    
    X = cv.fit_transform(X)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    
    model = LogisticRegression()
    fit = model.fit(X_train, y_train)
    
    y_pred = fit.predict(X_test)
    
    report = classification_report(
        y_test, y_pred, target_names=('rural', 'urban'),
    )
    
    print(report)
    
    return cv, model

# %%
def print_rural(model, names, n=100):
    idxs = model.coef_[0].argsort()
    for idx in idxs[:n]:
        print(model.coef_[0][idx], names[idx])

# %%
def print_urban(model, names, n=100):
    idxs = np.flip(model.coef_[0].argsort(), 0)
    for idx in idxs[:n]:
        print(model.coef_[0][idx], names[idx])

# %%
ng1_cv, ng1_model = train_model(X, y, (1, 1))
# Out:
#              precision    recall  f1-score   support
#
#       rural       0.60      0.09      0.15    589392
#       urban       0.65      0.97      0.78   1030399
#
# avg / total       0.63      0.65      0.55   1619791

# %%
ng2_cv, ng2_model = train_model(X, y, (2, 2))
# Out:
#              precision    recall  f1-score   support
#
#       rural       0.61      0.07      0.12    589542
#       urban       0.65      0.98      0.78   1030249
#
# avg / total       0.63      0.65      0.54   1619791

# %%
ng3_cv, ng3_model = train_model(X, y, (3, 3))
# Out:
#              precision    recall  f1-score   support
#
#       rural       0.70      0.04      0.08    590159
#       urban       0.64      0.99      0.78   1029632
#
# avg / total       0.67      0.64      0.52   1619791

# %% [markdown]
# Why does precision diverge so much in the bigram / trigram models?

# %% [markdown]
# # Rural unigrams

# %%
names1 = ng1_cv.get_feature_names()

# %%
print_rural(ng1_model, names1)
# Out:
# -2.02698872156 inhg
# -1.66383952218 tune
# -1.52531048562 dew
# -1.45348569115 temp
# -1.36326584455 meteobridge
# -0.952830835429 album
# -0.932218472857 automatically
# -0.868415076634 00
# -0.682956662167 pm
# -0.604653906709 posted
# -0.57879126007 boys
# -0.525841403805 liked
# -0.524926712575 rain
# -0.505220031029 baro
# -0.500786972735 sale
# -0.496239287935 school
# -0.471438693133 wind
# -0.459794781178 article
# -0.458780588326 road
# -0.457470835251 congratulations
# -0.444986053832 town
# -0.433731409541 snow
# -0.409118232202 shop
# -0.407218217147 weather
# -0.405409112251 playlist
# -0.401209971882 drinking
# -0.382123715052 area
# -0.379132610414 spring
# -0.378165919116 luck
# -0.372609548318 lmfao
# -0.36049754178 gt
# -0.346299699308 august
# -0.343608815658 enter
# -0.342554760595 center
# -0.340608711913 box
# -0.334362042465 meeting
# -0.332196773896 girls
# -0.328813379276 added
# -0.326303235192 market
# -0.325667207983 local
# -0.325270824553 greatest
# -0.323993332625 open
# -0.314681085411 space
# -0.308061147943 2nd
# -0.303404389935 visit
# -0.303083897314 field
# -0.299947398601 available
# -0.290805985586 home
# -0.281487844338 september
# -0.280481973313 fire
# -0.275681767044 students
# -0.27427459744 saturday
# -0.272535764438 massachusetts
# -0.270888766632 win
# -0.264851719884 rn
# -0.262077815137 45
# -0.261618310538 following
# -0.259491230574 dog
# -0.259159766788 final
# -0.258777642843 bro
# -0.25236813201 clean
# -0.250637779563 class
# -0.250288354961 drive
# -0.247839278012 issues
# -0.246104606068 north
# -0.24433468705 birthday
# -0.239249472816 ma
# -0.238817505055 summer
# -0.236273433436 due
# -0.235737544774 mr
# -0.234633168015 house
# -0.225949425481 100
# -0.223243263799 awesome
# -0.218718347522 29
# -0.217271588692 family
# -0.210615783639 checked
# -0.20583985004 student
# -0.20526631954 save
# -0.201616260122 woman
# -0.200753641977 july
# -0.199785667215 our
# -0.198096962478 check
# -0.197791460159 away
# -0.197263679137 lt
# -0.196600752063 crazy
# -0.195645346332 today
# -0.192698398388 mom
# -0.190285061446 nigga
# -0.190185571117 water
# -0.189888381661 thursday
# -0.188990479882 special
# -0.188267056735 30
# -0.18643780946 april
# -0.186071819182 wish
# -0.18408222996 england
# -0.183652142844 fun
# -0.183218524567 sports
# -0.180946918428 current
# -0.18013944931 day
# -0.17733449208 sunday

# %% [markdown]
# # Urban unigrams

# %%
print_urban(ng1_model, names1)
# Out:
# 3.80907821051 eastern
# 2.6412464023 wire
# 1.52931368697 من
# 1.38820291835 solo
# 1.15928581508 boston
# 1.15134329168 bruins
# 1.0984956611 الله
# 0.905394573572 recommend
# 0.820178877674 por
# 0.733627228102 details
# 0.718628475466 amazon
# 0.718367772532 celtics
# 0.670731439063 nba
# 0.668023383826 apply
# 0.585885668126 fit
# 0.563867117196 sox
# 0.558563774723 playing
# 0.547708800489 report
# 0.529489408663 jersey
# 0.528208059679 access
# 0.502443916391 data
# 0.501130236935 rt
# 0.486923973541 opening
# 0.486772367137 listen
# 0.477635942668 thomas
# 0.472956419329 york
# 0.467709984798 train
# 0.431850171025 marketing
# 0.418089920125 tweets
# 0.414858187999 brand
# 0.368677705268 until
# 0.340558712349 google
# 0.337254427541 99
# 0.334732550943 research
# 0.321364852326 digital
# 0.32018591512 tickets
# 0.313750593826 sales
# 0.309864852742 tech
# 0.300210803256 case
# 0.296698697801 says
# 0.283155205827 content
# 0.277900752873 live
# 0.274708484886 hi
# 0.274217660092 radio
# 0.270864441348 men
# 0.268758868614 la
# 0.2660689556 latest
# 0.26027752066 stream
# 0.25699123656 dm
# 0.256926315024 smart
# 0.252595211655 also
# 0.245753205465 jobs
# 0.237503807883 david
# 0.234889831728 review
# 0.232665762341 interview
# 0.23254387593 bc
# 0.224662268564 sharing
# 0.220578519216 tweet
# 0.216384961701 en
# 0.21499271249 cover
# 0.209229537588 imagine
# 0.208212530016 ways
# 0.20654772813 interested
# 0.203516032265 trade
# 0.20133121799 ppl
# 0.200594740166 09
# 0.198794737497 smh
# 0.198067580369 non
# 0.196377003358 que
# 0.192089094565 star
# 0.191439769036 unfollowed
# 0.191163905232 view
# 0.190844228911 law
# 0.188715437572 manager
# 0.187850144404 song
# 0.184861770746 based
# 0.184562930639 size
# 0.184485537706 asked
# 0.182212287096 record
# 0.179416327297 story
# 0.179224783953 deep
# 0.178342522969 via
# 0.178320095321 im
# 0.177875909396 14
# 0.177361733884 de
# 0.177332654288 hey
# 0.177295636515 email
# 0.176460628368 white
# 0.17480246745 social
# 0.174479986851 die
# 0.174160768289 its
# 0.1732751477 haha
# 0.173166251611 science
# 0.170762793491 card
# 0.169982230674 write
# 0.168013693381 oh
# 0.165868038769 women
# 0.165563696454 company
# 0.164109648318 piece
# 0.164078875557 mean

# %% [markdown]
# # Rural bigrams

# %%
names2 = ng2_cv.get_feature_names()

# %%
print_rural(ng2_model, names2)
# Out:
# -4.9340273553 dew point
# -2.91335962289 the album
# -2.68794271734 pinned to
# -2.0978639792 tune in
# -1.75339365439 open house
# -1.59950809549 00 pm
# -1.58551285047 added video
# -1.40644332212 automatically checked
# -1.35279313274 the market
# -1.23196105135 inhg via
# -1.23196105135 via meteobridge
# -1.2074298267 for sale
# -1.17652872951 click for
# -0.883216718488 to facebook
# -0.850575658896 people in
# -0.834859586663 2017 at
# -0.830861400954 for chance
# -0.672094847698 liked video
# -0.671677015551 happy birthday
# -0.62814251575 your favorite
# -0.627562509675 lt gt
# -0.623124384397 high school
# -0.621264387894 posted new
# -0.604699965477 gt gt
# -0.599055457178 baro 29
# -0.552269319657 rain 00in
# -0.552269319657 00in baro
# -0.526375078164 0mph rain
# -0.523600216545 see our
# -0.516465340455 best of
# -0.509924601434 real estate
# -0.485164936393 help you
# -0.48318813798 the day
# -0.480107414414 posted photo
# -0.467424307182 ma and
# -0.458248176333 more for
# -0.437743154587 me automatically
# -0.436969153759 click to
# -0.420727326582 to our
# -0.41794557688 good luck
# -0.414817008299 let us
# -0.407084162837 in and
# -0.38292866658 congrats to
# -0.363801020352 learn more
# -0.36044798644 check it
# -0.360405694068 on saturday
# -0.355983976157 latest the
# -0.355962682121 year old
# -0.355912295582 earned the
# -0.350479191176 don forget
# -0.349578912977 new england
# -0.331364051775 out this
# -0.327406058194 what is
# -0.322734034497 from your
# -0.319582849787 to win
# -0.317795031527 for pisces
# -0.316185257788 miss you
# -0.314825727569 of our
# -0.311119908584 with download
# -0.307210009588 on tuesday
# -0.303244619731 we love
# -0.296803687435 join us
# -0.285918695165 on our
# -0.278990112998 day of
# -0.278727458196 we are
# -0.278171221814 on wednesday
# -0.277831655694 to save
# -0.276217182662 this summer
# -0.271725664087 be at
# -0.270027344749 check out
# -0.269301725167 just earned
# -0.267023817105 view our
# -0.259417891045 how you
# -0.25469657577 for our
# -0.254627769369 lt lt
# -0.252149652922 we will
# -0.248984887953 just want
# -0.248430038321 new year
# -0.24540967256 on your
# -0.244218614603 out our
# -0.24334511706 due to
# -0.240073272581 you had
# -0.239455626881 we have
# -0.238162009958 on thursday
# -0.236177051733 did you
# -0.236141383927 at home
# -0.235397592634 read about
# -0.233785034463 the week
# -0.22810940938 get out
# -0.226835350606 about our
# -0.225306914477 how about
# -0.222248881715 woke up
# -0.22086245015 you will
# -0.216131086875 you love
# -0.21031057544 let go
# -0.209658494437 is how
# -0.209172690755 forward to
# -0.205629015886 for all
# -0.204299952396 the perfect
# -0.203646090589 download today

# %% [markdown]
# # Urban bigrams

# %%
print_urban(ng2_model, names2)
# Out:
# 6.12536510851 us eastern
# 5.54221168615 solo por
# 5.43281087334 com gt
# 5.31267103533 via amazon
# 4.71225490013 report at
# 4.11133515366 listen live
# 3.22432609206 boston celtics
# 2.95267707896 boston bruins
# 1.57853616109 boston ma
# 1.47889395342 2017 us
# 1.46435557936 on amp
# 1.42935787839 isaiah thomas
# 1.33202311974 for details
# 1.18417333517 now playing
# 1.08801056319 and click
# 1.0796628803 re click
# 1.07083180932 via nyt
# 1.02970817563 ma check
# 0.944211140802 latest ma
# 0.883205644034 in boston
# 0.864872595202 great fit
# 0.807049147626 live on
# 0.699560528616 recommend anyone
# 0.69095971222 red sox
# 0.616896166718 to boston
# 0.607276457083 gt lt
# 0.594191771918 opening here
# 0.564448485736 here ma
# 0.560135177117 and on
# 0.547614018277 checked by
# 0.546488625127 how are
# 0.540886374871 ma click
# 0.533918870695 it here
# 0.529796424789 the boston
# 0.499540994821 now on
# 0.467247919867 chance of
# 0.453036420769 for work
# 0.412577489879 daily thanks
# 0.410070872772 ma view
# 0.37775239953 see it
# 0.372320848403 video to
# 0.332359648609 in 2017
# 0.314307875683 by on
# 0.303181358403 the us
# 0.299876323264 re read
# 0.299133521582 latest opening
# 0.28629646627 based on
# 0.286079656298 on how
# 0.273422734527 the celtics
# 0.272941797198 the follow
# 0.27232638691 and people
# 0.270601215902 to read
# 0.267382601488 unfollowed me
# 0.267068609972 york times
# 0.26702227715 him to
# 0.262233901433 the future
# 0.248649732707 social media
# 0.247354660257 this to
# 0.243278805484 to playlist
# 0.243269261016 ma this
# 0.242267455308 read the
# 0.228961085309 it really
# 0.221901556599 new york
# 0.214254041183 is really
# 0.213819590949 each other
# 0.213516063551 work in
# 0.210767348117 president trump
# 0.205468962301 about how
# 0.20457718686 for sharing
# 0.203647010133 of people
# 0.200982417695 to apply
# 0.200640167477 in on
# 0.19715165348 looking forward
# 0.196702378197 they were
# 0.193895176599 ways to
# 0.193662917179 in at
# 0.191558025892 oh my
# 0.189555358587 amp the
# 0.18859041468 know if
# 0.187654643601 which is
# 0.185211855727 am on
# 0.183422183223 how is
# 0.183363204135 as an
# 0.180371537521 talking about
# 0.179903479552 the end
# 0.178935174527 they re
# 0.177101527721 white house
# 0.176682001468 birthday to
# 0.176408809104 less than
# 0.171178133354 of his
# 0.170721038923 and are
# 0.170328027512 there was
# 0.169741087324 there are
# 0.166381010975 people followed
# 0.164913891126 this was
# 0.164723475387 our latest
# 0.163947546647 this might
# 0.163229965703 and how
# 0.162969964554 health care
# 0.162043035337 so it

# %% [markdown]
# # Rural trigrams

# %%
names3 = ng3_cv.get_feature_names()

# %%
print_rural(ng3_model, names3)
# Out:
# -5.57083507864 on radio danz
# -3.63054970132 wind mph barometer
# -3.34518541373 rain today 00
# -3.280014639 is on q106
# -3.280014639 on q106 country
# -3.1255147782 falls ny weather
# -3.1255147782 honeoye falls ny
# -3.06769921745 example twitter weather
# -3.06769921745 twitter weather data
# -3.01303028592 in steady temperature
# -2.88289683454 wind speed 0mph
# -2.58945415774 national weather service
# -1.99928366957 today 00 in
# -1.53178036494 severe thunderstorm warning
# -1.52307186509 more and more
# -1.48913220091 left in the
# -1.46045594102 just checked in
# -1.39246784115 good luck to
# -1.36559091991 and people unfollowed
# -1.32264994605 new photo to
# -1.25231886349 out my broadcast
# -1.24434024686 to your profile
# -1.23078147828 lt gt gt
# -1.15512673819 cast your vote
# -1.14720757242 unit name chet
# -1.14720757242 motion detection unit
# -1.14720757242 name chet home
# -1.14720757242 home date time
# -1.14720757242 chet home date
# -1.14720757242 detection unit name
# -1.10396502787 now available for
# -1.09330066176 happy birthday hope
# -1.07049714751 video to facebook
# -1.06535970144 in the running
# -0.994694369288 case you missed
# -0.9497022127 yasss it time
# -0.940396814693 bottom of the
# -0.925601131076 to show you
# -0.885376476491 لا إله إلا
# -0.868028814513 with download today
# -0.852864027455 it out here
# -0.838321598254 me on snapchat
# -0.82991835228 now playing on
# -0.82616697322 to see who
# -0.821421503091 rain since midnight
# -0.779270401549 way to go
# -0.759072000399 you to know
# -0.755658801218 in mplus places
# -0.755658801218 earning in mplus
# -0.744519003012 chance to win
# -0.734291361244 love you too
# -0.729581754963 enter to win
# -0.727380500811 sign the petition
# -0.719120178493 posted new video
# -0.715601830377 miss you too
# -0.698817129638 you and me
# -0.665793573057 just earned the
# -0.639883198918 who visits your
# -0.625722156076 all of our
# -0.613223899508 and one person
# -0.606073251009 go to bed
# -0.605548537738 we will be
# -0.601949918002 love you more
# -0.591777821117 anyone for this
# -0.581090875736 to know who
# -0.573318239478 entered giveaway for
# -0.57094898632 rain last 24
# -0.543150860267 top of the
# -0.53493816613 team see our
# -0.519447939428 have great day
# -0.512158613195 of the season
# -0.508573826367 my best friend
# -0.500914750109 me automatically checked
# -0.497662411571 thank you to
# -0.494272224677 wow just entered
# -0.488213209375 you missed it
# -0.48790187823 so tired of
# -0.485869736102 ready to go
# -0.485739452405 for chance to
# -0.483715042754 first day of
# -0.482111649412 join us for
# -0.479662166608 4th of july
# -0.470866808266 hope you had
# -0.46250872698 on the road
# -0.455318862815 added video to
# -0.45424286893 keep up the
# -0.450757668304 back to school
# -0.449922147674 on my mind
# -0.449172638676 to know that
# -0.446254783943 and click to
# -0.442598918225 one of our
# -0.441089002315 of the week
# -0.429174732057 you so much
# -0.427941066891 do you see
# -0.419498910955 in the morning
# -0.408497865787 in need of
# -0.403442213397 your twitter profile
# -0.40339716063 liked video the
# -0.400186296502 we re read
# -0.398340778605 one person unfollowed

# %% [markdown]
# # Urban trigrams

# %%
print_urban(ng3_model, names3)
# Out:
# 4.90555537594 flight spotted at
# 4.7252154362 10 minute guide
# 4.53995590192 miles away traveling
# 3.52502750963 airlines flight spotted
# 3.23136182996 york city news
# 2.67151760388 work in ca
# 2.50413651048 in san diego
# 2.34591697654 in los angeles
# 2.1258235665 post your tweet
# 2.09473678644 surely interest you
# 2.09473678644 should surely interest
# 2.09473678644 this should surely
# 2.02063228519 your tweet also
# 2.02063228519 tweet also at
# 1.89277433479 can you recommend
# 1.51547029993 com gt gt
# 1.45381027246 click to apply
# 1.42684169082 00 humidity is
# 1.42684169082 gmt 0000 utc
# 1.42684169082 current temperature is
# 1.42684169082 0000 utc current
# 1.42684169082 utc current temperature
# 1.39531984685 you are looking
# 1.23361951049 followed me and
# 1.13122187042 new video to
# 1.11397250174 checked in at
# 1.06937498641 link in bio
# 0.935476410747 latest opening here
# 0.928509021713 in with download
# 0.867254586975 click for details
# 0.842969446075 00 in humidity
# 0.784023203742 the 10 minute
# 0.776872207472 connect have great
# 0.715022071903 in new york
# 0.70871930382 me and people
# 0.698522687926 the new york
# 0.605048554124 have you heard
# 0.599583096049 behind the scenes
# 0.565361980702 our latest opening
# 0.558470455928 be great fit
# 0.529326649498 game of thrones
# 0.484095422552 can you please
# 0.468851785827 broadcast from my
# 0.467743322707 my broadcast from
# 0.457961935256 great fit for
# 0.445003917394 official music video
# 0.433543303357 new york city
# 0.420568001843 what is this
# 0.417268555843 sign up for
# 0.412170299226 what the fuck
# 0.406696030028 looking for work
# 0.397345506365 ve never been
# 0.395614941196 would ve been
# 0.393693143941 thank you so
# 0.388278282826 interested in in
# 0.388005727845 for following me
# 0.375517332582 to talk about
# 0.373252488423 the future of
# 0.371184295619 not to be
# 0.369930712371 in the us
# 0.363574161452 need to know
# 0.356062703079 for work in
# 0.352647737711 need to see
# 0.338600906431 at the same
# 0.336462301347 we re all
# 0.335886526154 on the same
# 0.319498593693 just added this
# 0.305164606029 to work with
# 0.303056804482 the fuck up
# 0.297003491006 thanks for sharing
# 0.296212641458 is the new
# 0.285100899702 at the gym
# 0.281217084315 around the world
# 0.280346193198 this is an
# 0.279727397244 so we can
# 0.278298884252 to go out
# 0.269583482675 had no idea
# 0.265034235419 me on the
# 0.263900767395 in the future
# 0.261315830919 in my head
# 0.260418348834 what going on
# 0.25569545198 have you seen
# 0.255569853774 this is how
# 0.253419784911 do it for
# 0.253371713333 to know about
# 0.252771463619 get to the
# 0.245340120208 these are the
# 0.245068747722 follow happy to
# 0.241774815603 the fuck is
# 0.241111060351 hit me up
# 0.238588831545 shout out to
# 0.238314347514 and they re
# 0.235583835184 the best way
# 0.235420159472 they re not
# 0.234586719653 posted new photo
# 0.234141531315 you know what
# 0.233500980249 on my way
# 0.229398048023 what happens when
# 0.229198466344 trying to make
# 0.227818655908 you for the
